# %%
# import xlrd
# copper_data = pd.read_excel('D:/projects/Archie Copper/sp_capital_iq_copper.xls', sheet_name='2025Y')
# # Change all 'NA' in the dataset to blank
# copper_data = copper_data.fillna("")
# copper_data.to_excel('D:/projects/Archie Copper/copper_data_cap_iq.xlsx')
