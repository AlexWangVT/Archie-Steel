# %%
import pandas as pd

# %%
iron_ore_df = pd.read_excel('../data/Processed_data/iron_mine_w_cost_FeContent.xlsx', sheet_name='Sheet1')
iron_ore_df.head()
# Out:
#    Unnamed: 0   GEM Asset ID        Asset name (English)  \
# 0           0  P100000129290                Ghoryan Mine
# 1           1  P100000128013                Hajigak Mine
# 2           2  P100000129288                  Herat Mine
# 3           3  P100000129289                Syadara Mine
# 4           4  P100000128018  FERAAL Ghara Djebilet Mine
#
#   Asset name (other language)           Coordinates        Lat        Lon  \
# 0                         NaN  34.012090, 61.564895  34.012090  61.564895
# 1                         NaN  34.667981, 68.062676  34.667981  68.062676
# 2                         NaN  34.123862, 61.681827  34.123862  61.681827
# 3                         NaN  34.619615, 66.896422  34.619615  66.896422
# 4                         NaN  26.766298, -7.333398  26.766298  -7.333398
#
#          City State/Province      Country  ... Fifth Owner Country  \
# 0     Ghurian          Herat  Afghanistan  ...                 NaN
# ...
